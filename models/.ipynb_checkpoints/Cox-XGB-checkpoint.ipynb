# %%
import csv
import pandas as pd
import shap
import sklearn
import numpy as np
import matplotlib
import interpret.glassbox
import xgboost
import matplotlib.pylab as pl
from sklearn.model_selection import train_test_split

data = pd.read_csv('../cohort.csv')

# %%
y = data['time']
y = y.head(1000)
X = data.drop(['time'], axis = 1)
X = X.drop(['event'], axis = 1)
X=X.head(1000)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=20)

# %%
params = {
    'eta': 0.001,
    "max_depth": 3,
    'min_child_weight': 2.19,
    'reg_alpha': 0.17,
    'reg_lambda': 0.22,
    "objective": "survival:cox",
    "subsample":  0.89,
    "predictor": "gpu_predictor"
}

# %%
def c_statistic_harrell(pred, labels):
    total = 0
    matches = 0
    for i in range(len(labels)):
        for j in range(len(labels)):
            if int(labels[j]) > 0 and abs(int(labels[i])) > int(labels[j]):
                total += 1
                if pred[j] > pred[i]:
                    matches += 1
    return matches/total

# %%
num_boost_round=2000
dtrain = xgboost.DMatrix(X_train, label=y_train)
dval = xgboost.DMatrix(X_test, label=y_test)

watchlist = [(dval, 'eval'), (dtrain, 'train')]
xgb_model = xgboost.train(params, dtrain, num_boost_round,
                      evals=watchlist,
                      verbose_eval=500)

predictions = xgb_model.predict(dval,
                            ntree_limit=xgb_model.best_iteration + 1)

xgb_test_score = c_statistic_harrell(predictions, list(y_test))
print("XGB Done:", xgb_test_score)
# Out:
# [0]	eval-cox-nloglik:5.18859	train-cox-nloglik:6.50721
# [500]	eval-cox-nloglik:5.18597	train-cox-nloglik:6.49197
# [1000]	eval-cox-nloglik:5.18853	train-cox-nloglik:6.48396
# [1500]	eval-cox-nloglik:5.19138	train-cox-nloglik:6.47848
# [1999]	eval-cox-nloglik:5.19390	train-cox-nloglik:6.47434
# XGB Done: 0.6617876051074432
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
shap_values = shap.TreeExplainer(xgb_model).shap_values(X)

# %%
matplotlib.use('tkagg',force=True)
from matplotlib import pyplot as plt
matplotlib.get_backend()
# %matplotlib inline

# %%
shap.summary_plot(shap_values, X)
# c-stat = 0.66
